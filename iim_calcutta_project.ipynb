# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahtab14H/BDDA-all/blob/main/iim_calcutta_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# 1.0.1
from sklearn.model_selection import train_test_split
from sklearn.ensemble import  RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# 1.0.2
from pathlib import Path
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# For skopt routines
! pip install scikit-optimize
# 0.1 For plotting skopt results
! pip install 'scikit-optimize[plots]'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 2.7 MB/s eta 0:00:00
# ...

# %%
#1.0 Clear ipython memory
#%reset -f

# 1.1 Data manipulation and plotting modules
import numpy as np
import pandas as pd


# 1.2 Data pre-processing
#     z = (x-mean)/stdev
from sklearn.preprocessing import StandardScaler as ss

# 1.3 Dimensionality reduction and noise removal
from sklearn.decomposition import PCA

# 1.4 Data splitting and model parameter search
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# 1.5 Model pipelining
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline

# 1.6 Hyperparameter optimization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

# %%
#1.9 Model evaluation metrics
from sklearn.metrics import accuracy_score, f1_score
#from sklearn.metrics import plot_roc_curve
from sklearn.metrics import confusion_matrix

# 1.10
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import plot_importance

# 1.11 Permutation feature importance
from sklearn.inspection import permutation_importance

# %%
#1.13 Used in Randomized parameter search
from scipy.stats import uniform
# 1.12 Misc
import time
import os
import gc
import random
# 1.13 Used in Randomized parameter search
from scipy.stats import uniform
from matplotlib.ticker import EngFormatter
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import statsmodels as sm
import scipy.stats as sps
import statsmodels.formula.api as smf
import numpy as np

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Mahtab14H/BDDA-all/main/Bank_Marketing_iim_calcutta.csv")

# %%
data
# Out:
#        customer_age customer_job marital_status hghest_education  \
# 0                34  blue-collar       divorced        secondary
# 1                34   technician        married        secondary
# 2                35   technician        married          unknown
# 3                57   management       divorced        secondary
# 4                28  blue-collar        married          primary
# ...             ...          ...            ...              ...
# 43093            47   management        married         tertiary
# 43094            61      retired        married        secondary
# 43095            24      student         single        secondary
# 43096            70      retired        married        secondary
# 43097            53  blue-collar        married          primary
#
#       credit_default  account_balance housing loan contact_mode  call_day  \
# 0                 no             -294     yes   no      unknown        12
# ...

# %%
data.isnull().sum()
# There are no null values in data . hence , no need to impute it
# Out:
# customer_age                 0
# customer_job                 0
# marital_status               0
# hghest_education             0
# credit_default               0
# account_balance              0
# housing                      0
# loan                         0
# contact_mode                 0
# call_day                     0
# call_month                   0
# call_duration                0
# campaign_count               0
# previous_campaign            0
# previous_campaign_count      0
# previous_campaign_outcome    0
# deposites_purchased          0
# dtype: int64

# %%
data.describe()
# Out:
#        customer_age  account_balance      call_day  call_duration  \
# count  43098.000000     43098.000000  43098.000000   43098.000000
# mean      40.950021      1400.466750     16.225208     257.840596
# std       10.671794      3081.352007      8.291505     257.886291
# min       18.000000     -8019.000000      1.000000       0.000000
# 25%       33.000000        76.000000      9.000000     102.000000
# 50%       39.000000       473.000000     17.000000     179.000000
# 75%       48.000000      1489.000000     22.000000     319.000000
# max       95.000000    102127.000000     31.000000    4918.000000
#
#        campaign_count  previous_campaign  previous_campaign_count
# count    43098.000000       43098.000000             43098.000000
# mean         2.806279          41.983062                 0.602371
# std          3.156180         101.836452                 2.347143
# min          1.000000          -1.000000                 0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43098 entries, 0 to 43097
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_age               43098 non-null  int64
#  1   customer_job               43098 non-null  object
#  2   marital_status             43098 non-null  object
#  3   hghest_education           43098 non-null  object
#  4   credit_default             43098 non-null  object
#  5   account_balance            43098 non-null  int64
#  6   housing                    43098 non-null  object
#  7   loan                       43098 non-null  object
#  8   contact_mode               43098 non-null  object
#  9   call_day                   43098 non-null  int64
#  10  call_month                 43098 non-null  object
#  11  call_duration              43098 non-null  int64
#  12  campaign_count             43098 non-null  int64
# ...

# %%
data.shape
data['customer_job'].value_counts()
# Out:
# (43098, 17)
# management       9157
# blue-collar      9039
# technician       7297
# admin.           4905
# services         3901
# retired          2190
# self-employed    1528
# entrepreneur     1426
# unemployed       1252
# housemaid        1218
# student           905
# unknown           280
# Name: customer_job, dtype: int64

# %%
data['hghest_education'].value_counts()
# Out:
# secondary    22045
# tertiary     12887
# primary       6443
# unknown       1723
# Name: hghest_education, dtype: int64

# %%
# here , student and unknown makes a small chunk

# %%
data['contact_mode'].value_counts()
# Out:
# cellular     29217
# unknown      10981
# telephone     2900
# Name: contact_mode, dtype: int64

# %%
# Here , major contact mode is of cellular type and least is of telephone type

# %%
data['marital_status'].value_counts()
# Out:
# married     25939
# single      12232
# divorced     4927
# Name: marital_status, dtype: int64

# %%
Pie_chart= px.pie(data, title='credit default ', values='Units Sold',  color_discrete_sequence=["#0083B8"], names='Product')
Pie_chart.show()
